# %%
# Import Dependencies
import pandas as pd

# %%
# File to Load

# Read the modified GoodReads csv and store into Pandas DataFrame
books_df = pd.read_csv("Resources/books_clean.csv")
books_df
# Out:
#             ISBN  Publication Year  \
# 0      439023483            2008.0
# 1      439554934            1997.0
# 2      316015849            2005.0
# 3       61120081            1960.0
# 4      743273567            1925.0
# ...          ...               ...
# 9995   441019455            2010.0
# 9996  067973371X            1990.0
# 9997  039330762X            1977.0
# 9998    61711527            2011.0
# 9999   375700455            1998.0
#
#                                          Original Title  \
# 0                                      The Hunger Games
# 1              Harry Potter and the Philosopher's Stone
# 2                                              Twilight
# 3                                 To Kill a Mockingbird
# 4                                      The Great Gatsby
# ...                                                 ...
# 9995                                         Bayou Moon
# 9996                                   Means of Ascent
# ...

# %%
# Calculate the number of unique authors in the DataFrame
books_df["Authors"].nunique()
# Out:
# 4664

# %%
# Calculate the earliest/latest year a book was published
books_df["Publication Year"].min()
#books_df["Publication Year"].max()
# Out:
# -1750.0

# %%
# Calculate the total reviews for the entire dataset
# Hint: use the pandas' sum() method to get the sum for each row

books_df["Total Reviews"] = books_df.iloc[:,4:].sum(axis = 1)
books_df
# Out:
#             ISBN  Publication Year  \
# 0      439023483            2008.0
# 1      439554934            1997.0
# 2      316015849            2005.0
# 3       61120081            1960.0
# 4      743273567            1925.0
# ...          ...               ...
# 9995   441019455            2010.0
# 9996  067973371X            1990.0
# 9997  039330762X            1977.0
# 9998    61711527            2011.0
# 9999   375700455            1998.0
#
#                                          Original Title  \
# 0                                      The Hunger Games
# 1              Harry Potter and the Philosopher's Stone
# 2                                              Twilight
# 3                                 To Kill a Mockingbird
# 4                                      The Great Gatsby
# ...                                                 ...
# 9995                                         Bayou Moon
# 9996                                   Means of Ascent
# ...

# %%
# Place all of the data found into a summary DataFrame
books_df[["Publication Year", "Total Reviews"]].describe()
# Out:
#        Publication Year  Total Reviews
# count       9979.000000   1.000000e+04
# mean        1981.987674   1.790620e+05
# std          152.576665   5.034114e+05
# min        -1750.000000   1.653000e+04
# 25%         1990.000000   4.631625e+04
# 50%         2004.000000   7.149750e+04
# 75%         2011.000000   1.377450e+05
# max         2017.000000   1.482710e+07
